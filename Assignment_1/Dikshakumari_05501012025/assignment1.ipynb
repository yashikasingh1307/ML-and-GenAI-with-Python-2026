# %%
#Q1
length=5
breadth=4
Area=length*breadth
print(Area)
# Out:
# 20

# %%
# Q-2 Find simple interest.

p = 10000
r = 5
t = 2

si = (p * r * t) / 100

print("Simple Interest =", si)
# Out:
# Simple Interest = 1000.0

# %%
# Q-3 Convert temperature from celsius to farhenheit.

c = 25

f = (c * 9/5) + 32

print("Fahrenheit =", f)
# Out:
# Fahrenheit = 77.0

# %%
# Q-4 Calculate average of 3 numbers.

a = 10
b = 20
c = 30

avg = (a + b + c) / 3

print("Average =", avg)
# Out:
# Average = 20.0

# %%
#To find square and cube of a number
a=float(input("Enter a number"))
square=a**2
cube=a**3
print("The square and cube of the number respectively are :",square,cube)
# Out:
# Enter a number4
# The square and cube of the number respectively are : 16.0 64.0

# %%
#To swap two numbers without third variable
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a,b=b,a
print("After swapping :a=",a,"b= ",b)
# Out:
# Enter a number:4
# Enter a number:5
# After swapping :a= 5 b=  4

# %%
#To create a student report program
# Student Report Program

name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

english = float(input("Enter English marks: "))
maths = float(input("Enter Maths marks: "))
science = float(input("Enter Science marks: "))
sanskrit = float(input("Enter Sanskrit marks: "))

total = english + maths + science + sanskrit
percentage = (total / 400) * 100

print("\n----- STUDENT REPORT -----")
print("Name:", name)
print("Roll Number:", roll_no)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Enter student name: Diksha kumari
# Enter roll number: 55
# Enter English marks: 98
# Enter Maths marks: 97
# Enter Science marks: 94
# Enter Sanskrit marks: 100
#
# ----- STUDENT REPORT -----
# Name: Diksha kumari
# Roll Number: 55
# Total Marks: 389.0
# Percentage: 97.25 %
