# %%
# Find area of rectangle
length = int(input("Enter length : "))
width = int(input("Enter width : "))
area = length * width
print("Area of rectangle is : ", area)
# Out:
# Enter length : 10
# Enter width : 10
# Area of rectangle is :  100

# %%
# Find simple interest
prin = int(input("Enter principal amount : "))
rate = float(input("Enter rate of interest : "))
time = int(input("Enter time : "))
si = prin * rate * time / 100
print("Simple interest is : ", si)
# Out:
# Enter principal amount : 20
# Enter rate of interest : 0.5
# Enter time : 2
# Simple interest is :  0.2

# %%
# Convert tempreature from Celsius to Fahrenhiet
celsius = float(input("Enter temperature in celsius : "))
fahrenheit = (celsius * 9/5) + 32
print("Tempreature in Fahrenheit : ", fahrenheit)
# Out:
# Enter temperature in celsius : 20
# Tempreature in Fahrenheit :  68.0

# %%
# Calculate average of three numbers
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
num3 = int(input("Enter third number : "))
avg = (num1 + num2 + num3) / 3
print("Average of three numbers : ", avg)
# Out:
# Enter first number : 10
# Enter second number : 5
# Enter third number : 2
# Average of three numbers :  5.666666666666667

# %%
# Find square and cube of a number
num = int(input("Enter a number : "))
square = num ** 2
cube = num ** 3
print("Square of a number : ", square)
print("Cube of a number : ", cube)
# Out:
# Enter a number : 2
# Square of a number :  4
# Cube of a number :  8

# %%
# Swap two number without third variable
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print(num1, num2)
# Out:
# Enter first number : 2
# Enter second number : 3
# 3 2

# %%
# Student Report Program
roll = int(input("Enter roll number : "))
name = input("Enter name : ")

#INPUT MARKS
math = float(input("Enter marks in Math: "))
english = float(input("Enter marks in English: "))
science = float(input("Enter marks in Science: "))
history = float(input("Enter marks in History: "))
computer = float(input("Enter marks in Computer: "))

#CALCULATE TOTAL AND PERCENTAGE
total = math + english + science + history + computer      #TOTAL
percentage = total / 5                                     #PERCENTAGE

#OUTPUT DISPLAYED ON SCREEN
print("\nSTUDENT REPORT")
print("\nRoll Number: ", roll)
print("Name: ", name)
print("Math: ", math)
print("English: ", english)
print("Science: ", science)
print("History: ", history)
print("Computer: ", computer)
print("Total Grade", total)
print("Percentage: ",percentage,"%")
# Out:
# Enter roll number : 1
# Enter name : Khushi
# Enter marks in Math: 75
# Enter marks in English: 75
# Enter marks in Science: 85
# Enter marks in History: 85
# Enter marks in Computer: 95
#
# STUDENT REPORT
#
# Roll Number:  1
# Name:  Khushi
# Math:  75.0
# English:  75.0
# Science:  85.0
# History:  85.0
# Computer:  95.0
# Total Grade 415.0
# Percentage:  83.0 %
