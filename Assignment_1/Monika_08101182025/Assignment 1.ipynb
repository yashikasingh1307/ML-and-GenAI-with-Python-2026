# %%
# Q- 1 Find Area of redctangle.

length = 10
breadth = 5
area = length * breadth
print("Area of Rectangle =", area)
# Out:
# Area of Rectangle = 50

# %%
# Q-2 Find simple interest.

p = 10000
r = 5
t = 2

si = (p * r * t) / 100

print("Simple Interest =", si)
# Out:
# Simple Interest = 1000.0

# %%
# Q-3 Convert temperature from celsius to farhenheit.

c = 25

f = (c * 9/5) + 32

print("Fahrenheit =", f)
# Out:
# Fahrenheit = 77.0

# %%
# Q-4 Calculate average of 3 numbers.

a = 10
b = 20
c = 30

avg = (a + b + c) / 3

print("Average =", avg)
# Out:
# Average = 20.0

# %%
# Q-5 Find square and cube of a number.

n = 5

square = n * n
cube = n * n * n

print("Square =", square)
print("Cube =", cube)
# Out:
# Square = 25
# Cube = 125

# %%
# Q-6 Swap two numbers without third variable.

a = 10
b = 20

a = a + b
b = a - b
a = a - b

print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10

# %%
# Q-7 Create a student report program that take studet deatils using input(), store marks in variable, calculate total percentage, use comments, use proper indentation.

# Student Details

name = input("Enter Student Name: ")
roll_no = input("Enter Roll Number: ")

# Marks Input

m1 = int(input("Enter Marks of Subject 1: "))
m2 = int(input("Enter Marks of Subject 2: "))
m3 = int(input("Enter Marks of Subject 3: "))

# Total and Percentage

total = m1 + m2 + m3
percentage = total / 3

# Display Report

print("\n----- STUDENT REPORT -----")
print("Name :", name)
print("Roll No :", roll_no)
print("Total Marks :", total)
print("Percentage :", percentage)
# Out:
# Enter Student Name:  Monika
# Enter Roll Number:  081
# Enter Marks of Subject 1:  90
# Enter Marks of Subject 2: 80
# Enter Marks of Subject 3: 98
#
# ----- STUDENT REPORT -----
# Name :  Monika
# Roll No :  081
# Total Marks : 268
# Percentage : 89.33333333333333
