# %%
#Name - Mugdha Kumar
#Course - CSE2
#Enrollment no - 11201012025

# %%
#1. Find Area of Rectangle
length = float(input("Enter length = "))
bredth = float(input("Enter bredth ="))
area = float(length*bredth)
print ("Area of the rectangle is ",area)
# Out:
# Enter length = 5
# Enter bredth =6
# Area of the rectangle is  30.0

# %%
#2. Find Simple Interest
p = float(input("Enter principal amount = "))
r = float(input("Enter rate of interest = "))
t = float(input("Enter time period = "))
Simple_interest = float(p*r*t)
print ("Simple interest ", p*r*t)
# Out:
# Enter principal amount = 60000
# Enter rate of interest = 11
# Enter time period = 15
# Simple interest  9900000.0

# %%
#3. Covert temperature in celsius to Fahrenheit
celsius = float(input("Enter value of temperature in celsius = "))
fahrenheit = (celsius*9/5)+32
print("Temperature in fahrenheit = ", fahrenheit)
# Out:
# Enter value of temperature in celsius = 45
# Temperature in fahrenheit =  113.0

# %%
#4. Average of three numbers
a = int(input("Enter first number = "))
b = int(input("Enter second number ="))
c = int(input("Enter third number = "))
avg = (a+b+c)/3
print("Average of the three numbers is ", avg)
# Out:
# Enter first number = 45
# Enter second number =50
# Enter third number = 43
# Average of the three numbers is  46.0

# %%
#5. Find the square and cube of a number
num = int(input("Enter the number"))
print("Square of the number is ", num*num)
print("Cube of the number is ",num**num*num)
# Out:
# Enter the number2
# Square of the number is  4
# Cube of the number is  8

# %%
#6. Swap two numbers without third variable
a = int(input("Enter first number = "))
b = int(input("Enter second number = "))
a = a+b
b = a-b
a = a-b
print("Value of the entered numbers after swapping is ", a, "and", b)
# Out:
# Enter first number = 2
# Enter second number = 3
# Value of a the entered numbers after swapping is  3 and 2

# %%
#7. Student Result System
name = input("Enter name = ")
roll_no = int(input("Enter roll no = "))
subjects = int(input("Enter number of subjects = "))
total = 0
for i in range (0, subjects):
  marks = float(input(f"Enter marks in subject{i}: "))
  total +=marks
score = (total/subjects)

if (score>90):
  print("A+ grade")
elif (score>80):
  print("A grade")
elif(score>70):
  print("B+ grade")
elif (score>60):
  print("B grade")
else:
  print("Fail")
