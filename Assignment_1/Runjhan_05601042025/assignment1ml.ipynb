# %% [markdown]
# # 1.Find area of rectangle.

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area of rectangle =", area)
# Out:
# Enter length: 67
# Enter width: 78
# Area of rectangle = 5226.0

# %% [markdown]
# # 2.Find simple interest.

# %%
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest: "))
time = float(input("Enter time (years): "))

simple_interest = (principal * rate * time) / 100

print("Simple Interest =", simple_interest)
# Out:
# Enter principal amount: 45000
# Enter rate of interest: 7
# Enter time (years): 5
# Simple Interest = 15750.0

# %% [markdown]
# ## 3. Convert temperature from Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius: 25
# Temperature in Fahrenheit = 77.0

# %% [markdown]
# # 4. Calculate average of 3 numbers.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3) / 3

print("Average =", average)
# Out:
# Enter first number: 82
# Enter second number: 88
# Enter third number: 89
# Average = 86.33333333333333

# %% [markdown]
# #5. Find square and cube of a number.

# %%
num = int(input("Enter a number: "))

square = num ** 2
cube = num ** 3

print("Square =", square)
print("Cube =", cube)
# Out:
# Enter a number: 34
# Square = 1156
# Cube = 39304

# %% [markdown]
# # 6. Swap Two Numbers Without Using Third Variable

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a, b = b, a

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 6
# Enter second number: 9
# After swapping:
# a = 9
# b = 6

# %% [markdown]
# # 7. Create a Student Report Program that take student details using input), Store marks in variables, Calculate total and percentage, Use comments, Use proper indentation

# %%
# Student Report Program

# Input for student details
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Input of marks for 5 subjects
a = float(input("Enter marks for Sub 1: "))
b = float(input("Enter marks for Sub 2: "))
c = float(input("Enter marks for Sub 3: "))
d = float(input("Enter marks for Sub 4: "))
e = float(input("Enter marks for Sub 5: "))

# Calculate total marks
totalmarks = a + b + c + d + e

# Calculate percentage
percentage = totalmarks / 5

# Display report
print("\n----- STUDENT REPORT -----")
print("Name:", name)
print("Roll Number:", roll_no)
print("Total Marks:", totalmarks)
print("Percentage:", percentage, "%")
# Out:
# Enter student name: supriya
# Enter roll number: 23
# Enter marks for Sub 1: 87
# Enter marks for Sub 2: 78
# Enter marks for Sub 3: 86
# Enter marks for Sub 4: 90
# Enter marks for Sub 5: 87
#
# ----- STUDENT REPORT -----
# Name: supriya
# Roll Number: 23
# Total Marks: 428.0
# Percentage: 85.6 %
