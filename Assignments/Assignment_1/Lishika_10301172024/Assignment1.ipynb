# %% [markdown]
# # Assignment **1**

# %% [markdown]
# ##Find Area of Rectangle

# %%
# Formula: Area = Length × Breadth

length = float(input("Enter the length of the rectangle: "))
breadth = float(input("Enter the breadth of the rectangle: "))

area = length * breadth

print(f"Area of the rectangle = {area}")
# Out:
# Enter the length of the rectangle: 5.4
# Enter the breadth of the rectangle: 3.3
# Area of the rectangle = 17.82

# %% [markdown]
# ## Find Simple Interest

# %%
# Formula: SI = (Principal × Rate × Time) / 100

principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest (in %): "))
time = float(input("Enter the time period (in years): "))

simple_interest = (principal * rate * time) / 100

print(f"Simple Interest = {simple_interest}")
# Out:
# Enter the principal amount: 1000
# Enter the rate of interest (in %): 3
# Enter the time period (in years): 2
# Simple Interest = 60.0

# %% [markdown]
# ## Convert Temperature from Celsius to Fahrenheit

# %%
# Formula: F = (C × 9/5) + 32

celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print(f"{celsius}°C = {fahrenheit}°F")
# Out:
# Enter temperature in Celsius: 28
# 28.0°C = 82.4°F

# %% [markdown]
# ## Calculate Average of 3 Numbers

# %%
# Formula: Average = (num1 + num2 + num3) / 3

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

average = (num1 + num2 + num3) / 3

print(f"Average of {num1}, {num2} and {num3} = {average}")
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# Average of 2.0, 3.0 and 4.0 = 3.0

# %% [markdown]
# ## Find Square and Cube of a Number

# %%
# Square = num ** 2
# Cube   = num ** 3

num = float(input("Enter a number: "))

square = num ** 2
cube = num ** 3

print(f"Square of {num} = {square}")
print(f"Cube of {num}   = {cube}")
# Out:
# Enter a number: 4
# Square of 4.0 = 16.0
# Cube of 4.0   = 64.0

# %% [markdown]
# ## Swap Two Numbers Without a Third Variable

# %%
# Method: Using arithmetic (addition & subtraction)

a = int(input("Enter first number (a): "))
b = int(input("Enter second number (b): "))

print(f"Before swap: a = {a}, b = {b}")

# Swapping without a third variable
a = a + b   # a now holds the sum
b = a - b   # b gets the original value of a
a = a - b   # a gets the original value of b

print(f"After swap:  a = {a}, b = {b}")
# Out:
# Enter first number (a): 5
# Enter second number (b): 10
# Before swap: a = 5, b = 10
# After swap:  a = 10, b = 5

# %% [markdown]
# ## Student Report Program

# %%
# ---------- Student Details ----------
student_name = input("Enter student name: ")
roll_number = input("Enter roll number: ")
student_class = input("Enter class: ")

# ---------- Marks Input ----------
marks_maths = float(input("Enter marks in Maths (out of 100): "))
marks_science = float(input("Enter marks in Science (out of 100): "))
marks_english = float(input("Enter marks in English (out of 100): "))
marks_hindi = float(input("Enter marks in Hindi (out of 100): "))
marks_computer = float(input("Enter marks in Computer (out of 100): "))

# ---------- Calculations ----------
total_marks = marks_maths + marks_science + marks_english + marks_hindi + marks_computer
max_marks = 500  # 5 subjects × 100
percentage = (total_marks / max_marks) * 100

# ---------- Grades ----------
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 40:
    grade = "D"
else:
    grade = "F (Fail)"

# ---------- Report Display ----------
print("\n" + "="*40)
print("        STUDENT REPORT CARD")
print("="*40)
print(f"Name        : {student_name}")
print(f"Roll No.    : {roll_number}")
print(f"Class       : {student_class}")
print("-"*40)
print(f"Maths       : {marks_maths}")
print(f"Science     : {marks_science}")
print(f"English     : {marks_english}")
print(f"Hindi       : {marks_hindi}")
print(f"Computer    : {marks_computer}")
print("-"*40)
print(f"Total Marks : {total_marks} / {max_marks}")
print(f"Percentage  : {percentage:.2f}%")
print(f"Grade       : {grade}")
print("="*40)
# Out:
# Enter student name: Arun
# Enter roll number: 1
# Enter class: 5
# Enter marks in Maths (out of 100): 90
# Enter marks in Science (out of 100): 87
# Enter marks in English (out of 100): 88
# Enter marks in Hindi (out of 100): 95
# Enter marks in Computer (out of 100): 91
#
# ========================================
#         STUDENT REPORT CARD
# ========================================
# Name        : Arun
# Roll No.    : 1
# Class       : 5
# ----------------------------------------
# Maths       : 90.0
# Science     : 87.0
# English     : 88.0
# Hindi       : 95.0
# Computer    : 91.0
# ----------------------------------------
# Total Marks : 451.0 / 500
# Percentage  : 90.20%
# Grade       : A+
# ========================================
