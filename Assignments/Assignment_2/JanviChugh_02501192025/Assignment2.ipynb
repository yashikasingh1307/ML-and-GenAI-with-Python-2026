# %%
#Janvi_Chugh Assignnment 2

# %%
#Que1:sum of first 10 natural numbers
sum=0
for i in range(1,11):
  sum=sum+i
print("sum of first 10 natural  no.is :-",sum)
# Out:
# sum of first 10 natural  no.is :- 55

# %%
#Que2: Find factorial of a number
num = int(input("Enter a number: "))
fact = 1
for i in range(1, num + 1):
    fact = fact * i
print("Factorial of", num, "is:", fact)
# Out:
# Enter a number: 5
# Factorial of 5 is: 120

# %%
#Que3:Print Fibonacci Series
n = int(input("Enter the number of terms: "))
a = 0
b = 1
print("Fibonacci Series:")
for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c
# Out:
# Enter the number of terms: 4
# Fibonacci Series:
# 0 1 1 2

# %%
#Que4:Find greatest of three numbers
a=float(input("Enter first number:"))
b=float(input("Enter second number:"))
c=float(input("Enter third number:"))
if a>b and a>c:
    largest=a
elif b>a and b>c:
    largest=b
else:
    largest=c
print("Largest number:",largest)
# Out:
# Enter first number:4
# Enter second number:7
# Enter third number:1
# Largest number: 7.0

# %%
#Que5:Create Student Result System
# -	Input student details
# -	Input marks
# -	Calculate percentage
# -	Display grade
# -	Use:
# if-elif-else
# loops
# user input
student_name = input("Enter student name: ")
physics = int(input("Enter Physics marks: "))
chemistry = int(input("Enter Chemistry marks: "))
maths = int(input("Enter Maths marks: "))
total = physics + chemistry + maths
percentage = (total /300)*100
if percentage >= 90:
    grade = "A"
elif percentage >= 80:
    grade = "B"
elif percentage >= 70:
    grade = "C"
elif percentage >= 60:
    grade = "D"
else:
    grade = "F"
print("Student Name:", student_name)
print("Total Marks:", total)
print("Percentage:", percentage)
print("Grade:", grade)
# Out:
# Enter student name: Janvi Chugh
# Enter Physics marks: 99
# Enter Chemistry marks: 100
# Enter Maths marks: 96
# Student Name: Janvi Chugh
# Total Marks: 295
# Percentage: 98.33333333333333
# Grade: A
