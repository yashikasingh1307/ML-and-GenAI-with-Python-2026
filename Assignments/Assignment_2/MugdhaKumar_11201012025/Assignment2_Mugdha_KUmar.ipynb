# %%
#MUGDHA KUMAR - 11201012025
#1. Sum of First 10 Natural Numbers
sum = 0
for i in range (1,11):
  sum+=i
print("sum is ", sum)
# Out:
# sum is  55

# %%
#Factorial of a number
terms = int(input("Enter number of terms = "))
a = 0
b =1
for i in range (0, terms):
  print(a, end=" ")
  c=a+b
  a=b
  b=c
# Out:
# Enter number of terms = 5
# 0 1 1 2 3

# %%
#Fid the largest amonst three numbers
a = int(input("Enter first number = "))
b = int(input("Enter seconf number = "))
c = int(input("Enter third number = "))
if (a>b and a>c):
  print(a," is the largest amonst all the number")
elif (b>c and b>a):
  print(b, " is the largest amongst all the numbers")
else:
  print(c, " is the largest amongst all the numbers")
# Out:
# Enter first number = 45
# Enter seconf number = 43
# Enter third number = 21
# 45  is the largest amonst all the number

# %%
name = input("Enter name of the student = ")
roll_no = int(input("Roll no = "))
semester =int(input("Semester ="))
subjects = int(input("Enter no of subjects = "))
total = 0
for i in range(1, subjects+1):
  marks = int(input(f"Enter marks obtained in the subject {i} = "))
  total+=marks
percentage = total/subjects
print("Percentage = ", percentage, "%")
if(percentage>90):
  print("A+ grade")
elif(percentage>80):
  print("A grade")
elif(percentage>70):
  print("B+ grade")
elif(percentage>60):
  print("B grade")
elif(percentage>50):
  print("C+ grade")
else:
   print("fail")
# Out:
# Enter name of the student = riy
# Roll no = 112
# Semester =2
# Enter no of subjects = 3
# Enter marks obtained in the subject 1 = 89
# Enter marks obtained in the subject 2 = 34
# Enter marks obtained in the subject 3 = 79
# Percentage =  67.33333333333333 %
# B grade
