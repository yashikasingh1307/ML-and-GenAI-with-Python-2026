# %% [markdown]
# <a href="https://colab.research.google.com/github/chaxu8843-jpg/ML-and-GenAI-with-Python-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Area of rectangle
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
print("Area of rectangle =", area)
# Out:
# Enter length: 2
# Enter width: 4
# Area of rectangle = 8.0

# %%
# Simple interest
p = float(input("Enter principal: "))
r = float(input("Enter rate of interest: "))
t = float(input("Enter time (in years): "))
si = (p * r * t) / 100
print("Simple Interest =", si)
# Out:
# Enter principal: 100
# Enter rate of interest: 23
# Enter time (in years): 6
# Simple Interest = 138.0

# %%
# Convert Celsius to Fahrenheit
c = float(input("Enter temperature in Celsius: "))
f = (c * 9/5) + 32
print("Temperature in Fahrenheit =", f)
# Out:
# Enter temperature in Celsius: 32
# Temperature in Fahrenheit = 89.6

# %%
# Average of three numbers
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
avg = (a + b + c) / 3
print("Average =", avg)
# Out:
# Enter first number: 3
# Enter second number: 6
# Enter third number: 9
# Average = 6.0

# %%
# Square and cube of a number
n = float(input("Enter a number: "))
print("Square =", n ** 2)
print("Cube =", n ** 3)
# Out:
# Enter a number: 8
# Square = 64.0
# Cube = 512.0

# %%
# Swap two numbers without third variable
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
x, y = y, x
print("After swapping: x =", x, "y =", y)
# Out:
# Enter first number: 23
# Enter second number: 84
# After swapping: x = 84 y = 23

# %%
# Student Report Program
name = input("Enter student name: ")
roll = input("Enter roll number: ")

# Marks input
m1 = float(input("Enter marks in Subject 1: "))
m2 = float(input("Enter marks in Subject 2: "))
m3 = float(input("Enter marks in Subject 3: "))

# Calculations
total = m1 + m2 + m3
percentage = (total / 300) * 100

# Output
print("\n--- Student Report ---")
print("Name:", name)
print("Roll No:", roll)
print("Total Marks:", total)
print("Percentage:", percentage, "%")

# Comments
if percentage >= 75:
    print("Grade: Distinction")
elif percentage >= 60:
    print("Grade: First Class")
elif percentage >= 40:
    print("Grade: Pass")
else:
    print("Grade: Fail")
# Out:
# Enter student name: chaxu
# Enter roll number: 49
# Enter marks in Subject 1: 82
# Enter marks in Subject 2: 93
# Enter marks in Subject 3: 85
#
# --- Student Report ---
# Name: chaxu
# Roll No: 49
# Total Marks: 260.0
# Percentage: 86.66666666666667 %
# Grade: Distinction
