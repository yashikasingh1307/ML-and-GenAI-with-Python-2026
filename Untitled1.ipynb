# %% [markdown]
# <a href="https://colab.research.google.com/github/chaxu8843-jpg/ML-and-GenAI-with-Python-2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sum of first 10 natural numbers
sum_n = 0
for i in range(1, 11):
    sum_n += i
print("Sum of first 10 natural numbers =", sum_n)
# Out:
# Sum of first 10 natural numbers = 55

# %%
# Factorial of a number
n = int(input("Enter a number: "))
fact = 1
for i in range(1, n + 1):
    fact *= i
print("Factorial of", n, "is", fact)
# Out:
# Enter a number: 23
# Factorial of 23 is 25852016738884976640000

# %%
# Print Fibonacci Series
terms = int(input("Enter number of terms: "))
a, b = 0, 1
print("Fibonacci Series:")
for _ in range(terms):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms: 5
# Fibonacci Series:
# 0 1 1 2 3

# %%
# Find largest among 3 numbers
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

print("Largest number is:", largest)
# Out:
# Enter first number: 34
# Enter second number: 56
# Enter third number: 86
# Largest number is: 86.0

# %%
# Student Result System using if‑elif‑else, loops, and user input

# Input student details
name = input("Enter student name: ")
roll = input("Enter roll number: ")

# Input marks for subjects
num_subjects = int(input("Enter number of subjects: "))
total_marks = 0

for i in range(num_subjects):
    marks = float(input(f"Enter marks for subject {i + 1}: "))
    total_marks += marks

# Calculate percentage
percentage = (total_marks / (num_subjects * 100)) * 100

# Display grade
print("\n--- Student Result ---")
print("Name:", name)
print("Roll No:", roll)
print("Total Marks:", total_marks)
print("Percentage:", percentage, "%")

if percentage >= 75:
    grade = "Distinction"
elif percentage >= 60:
    grade = "First Class"
elif percentage >= 40:
    grade = "Pass"
else:
    grade = "Fail"

print("Grade:", grade)
# Out:
# Enter student name: chaxu
# Enter roll number: 49
# Enter number of subjects: 2
# Enter marks for subject 1: 45
# Enter marks for subject 2: 48
#
# --- Student Result ---
# Name: chaxu
# Roll No: 49
# Total Marks: 93.0
# Percentage: 46.5 %
# Grade: Pass
